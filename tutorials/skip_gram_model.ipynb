# %%
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified %s' % filename)
    else:
        print(statinfo.st_size)
        raise Exception('Failed to verify ' + filename + '. Can you get to it with a browser?')
    return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# What we are going to do now is to load the data in.
# The data are 100MB. The idea is to open the zip file, turn it into a string and then a list of strings using split.
# Only at that moment we can then use tf.compat.as_str to turn this list of strings into a list of string. We are sure that by using that this is happening.

# %%
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data
  
words = read_data(filename)
print(type(words))
print('Data size %d' % len(words))
# Out:
# <type 'list'>
# Data size 17005207

# %%
vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count = unk_count + 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
    return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'term', 'a', 'anarchism', 'as', 'term', 'originated', 'of']

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 300001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.292681
# Nearest to will: revoked, hermann, kapital, concrete, boston, pointing, succumb, murderers,
# Nearest to with: cbs, thirteenth, newcastle, bamako, digamma, lefty, uncharacteristic, bahraini,
# Nearest to american: repose, falcons, infiltration, bruin, ruble, throughout, messerschmitt, teotihuacan,
# Nearest to most: rulebook, kenny, consecutively, searchlight, ballets, flood, users, cheat,
# Nearest to six: cornelius, canaris, katsuhiro, estranged, lite, defections, blenheim, lucy,
# Nearest to on: defection, trumpets, scrolling, avro, dhaka, gibraltarians, tend, sculptors,
# Nearest to from: jaffa, ponty, unavailable, janssen, allotment, conjectural, reminds, momentous,
# Nearest to UNK: glaciations, timetable, khanum, eon, angered, mosiah, casting, ignorance,
# Nearest to see: ratify, waited, scott, mentality, ravine, kov, sending, nsg,
# Nearest to they: infirmary, vibrato, cantons, liszt, spread, doc, world, comprehend,
# Nearest to often: championship, exiting, addicted, rightful, nigger, quantification, solicitor, talent,
# Nearest to who: boyne, butler, dresden, insertions, heliocentric, pups, cartwright, name,
# Nearest to had: bal, murmur, rainforests, accurately, improves, eject, glycolipids, mesolithic,
# Nearest to be: vigo, motives, siddur, ragnar, grothendieck, meaningfully, airlines, spenser,
# Nearest to such: clouded, aquifer, monsignor, tolbert, psyche, exposed, oscillator, immediately,
# Nearest to which: plazas, disused, misheard, counterfeit, fared, mais, sheriff, sunni,
# Average loss at step 2000: 4.378383
# Average loss at step 4000: 3.876228
# Average loss at step 6000: 3.796963
# Average loss at step 8000: 3.754400
# Average loss at step 10000: 3.622045
# Nearest to will: can, may, would, succumb, infectious, sheng, zechariah, might,
# Nearest to with: in, between, by, for, literals, third, and, pynchon,
# Nearest to american: misty, bruin, phenomenon, crucified, throughout, dictation, visitation, qos,
# Nearest to most: rulebook, protagonists, users, equites, versatile, keating, cassation, gotha,
# Nearest to six: four, seven, eight, five, three, nine, two, zero,
# Nearest to on: in, from, fleischer, and, avro, former, sculptors, of,
# Nearest to from: in, and, by, inhabiting, on, to, after, jaffa,
# Nearest to UNK: claude, lyndon, khanum, arrangers, scientists, inspirations, de, maxima,
# Nearest to see: ratify, kov, ravine, organizations, sturgeon, ward, remedial, liberating,
# Nearest to they: he, we, it, sticks, you, sepp, there, who,
# Nearest to often: also, functions, quantification, anode, nigger, arterial, spoken, solicitor,
# Nearest to who: he, dresden, they, taxonomic, changeover, middlesex, tout, boyne,
# Nearest to had: has, have, was, rainforests, ther, accurately, renovate, would,
# Nearest to be: have, was, been, by, chandragupta, barron, become, computes,
# Nearest to such: clouded, known, berwick, arnulf, psyche, cursive, estimation, ado,
# Nearest to which: that, this, it, there, counterfeit, martov, also, clarendon,
# Average loss at step 12000: 3.576510
# Average loss at step 14000: 3.609970
# Average loss at step 16000: 3.578680
# Average loss at step 18000: 3.570211
# Average loss at step 20000: 3.543977
# Nearest to will: can, would, may, might, should, could, infectious, to,
# Nearest to with: between, in, through, lefty, by, or, soaemias, chauffeur,
# Nearest to american: throughout, misty, english, bruin, ruble, dictation, phenomenon, veer,
# Nearest to most: more, rulebook, quite, protagonists, users, versatile, rising, bundesrat,
# Nearest to six: seven, five, four, eight, nine, three, zero, two,
# Nearest to on: in, avro, fleischer, scenery, about, former, sculptors, beyond,
# Nearest to from: inhabiting, in, into, by, after, nitrile, for, snl,
# Nearest to UNK: dickey, terrorist, db, essays, rerum, oral, necessitates, greek,
# Nearest to see: kov, ward, organizations, but, preterist, bryce, remedial, spector,
# Nearest to they: he, we, there, who, you, it, she, not,
# Nearest to often: also, generally, quantification, actually, originally, functions, ccds, it,
# Nearest to who: he, they, she, which, also, never, still, that,
# Nearest to had: has, have, was, were, been, rainforests, renovate, marne,
# Nearest to be: have, by, been, was, were, barron, become, refer,
# Nearest to such: known, well, ado, these, clouded, seen, empowerment, berwick,
# Nearest to which: that, this, also, it, who, godlike, however, carpets,
# Average loss at step 22000: 3.529764
# Average loss at step 24000: 3.439697
# Average loss at step 26000: 3.412704
# Average loss at step 28000: 3.472355
# Average loss at step 30000: 3.407780
# Nearest to will: would, can, may, should, could, might, must, cannot,
# Nearest to with: between, undertakes, clue, fortran, in, pandemic, vases, using,
# Nearest to american: english, british, french, italian, bruin, veer, dictation, canadian,
# Nearest to most: more, quite, users, many, hideo, versatile, some, protagonists,
# Nearest to six: eight, seven, five, four, nine, three, zero, two,
# Nearest to on: in, avro, about, at, upon, through, under, within,
# Nearest to from: nitrile, inhabiting, in, after, into, acton, snl, cossack,
# Nearest to UNK: berliners, chez, dkw, charlie, restored, nls, offseason, hsv,
# Nearest to see: kov, stylized, sturgeon, parl, morphological, mondo, gunmen, spector,
# Nearest to they: he, we, there, you, it, who, not, she,
# Nearest to often: also, generally, usually, actually, sometimes, now, there, widely,
# Nearest to who: he, they, she, also, battleships, pax, which, purchases,
# Nearest to had: has, have, was, were, been, rainforests, uiuc, would,
# Nearest to be: been, refer, have, was, is, by, were, continue,
# Nearest to such: well, these, known, seen, kernels, many, ado, gambier,
# Nearest to which: that, this, also, carpets, there, it, often, what,
# Average loss at step 32000: 3.414285
# Average loss at step 34000: 3.444934
# Average loss at step 36000: 3.361832
# Average loss at step 38000: 3.494431
# Average loss at step 40000: 3.441738
# Nearest to will: would, can, may, could, should, might, must, cannot,
# Nearest to with: between, pandemic, through, territorial, using, lefty, when, by,
# Nearest to american: british, english, italian, animated, canadian, veer, dictation, genesee,
# Nearest to most: more, many, quite, quotients, some, versatile, hideo, all,
# Nearest to six: eight, seven, five, nine, four, zero, two, three,
# Nearest to on: upon, at, avro, in, through, within, about, epitome,
# Nearest to from: inhabiting, into, in, yielded, on, for, lynne, through,
# Nearest to UNK: drenthe, chagas, rationalize, lugo, rosie, sniper, paulo, recumbent,
# Nearest to see: scanty, mondo, stylized, gunmen, identifier, can, kolbe, bethlehem,
# Nearest to they: we, he, you, there, who, it, she, not,
# Nearest to often: usually, commonly, generally, sometimes, now, also, widely, actually,
# Nearest to who: he, they, she, also, which, still, never, vagus,
# Nearest to had: has, have, were, was, sevens, been, having, reboot,
# Nearest to be: been, refer, was, have, were, become, being, continue,
# Nearest to such: these, well, known, kernels, many, opposed, ado, ayla,
# Nearest to which: that, this, also, but, carpets, who, what, it,
# Average loss at step 42000: 3.423583
# Average loss at step 44000: 3.282680
# Average loss at step 46000: 3.410167
# Average loss at step 48000: 3.430087
# Average loss at step 50000: 3.436361
# Nearest to will: would, can, may, could, might, should, must, cannot,
# Nearest to with: between, in, fortran, for, undertakes, finalist, by, against,
# Nearest to american: british, italian, english, veer, french, film, african, animated,
# Nearest to most: more, many, bundesrat, versatile, some, very, hideo, satires,
# Nearest to six: seven, eight, four, five, three, nine, zero, two,
# Nearest to on: upon, in, through, during, avro, under, within, at,
# Nearest to from: into, through, inhabiting, nitrile, prescribing, in, back, of,
# Nearest to UNK: jean, storey, j, metis, v, michel, shuster, marie,
# Nearest to see: gunmen, ward, scanty, courtiers, stylized, sandworms, can, vara,
# Nearest to they: we, there, he, you, she, it, these, who,
# Nearest to often: usually, sometimes, commonly, generally, now, also, widely, still,
# Nearest to who: he, she, which, never, they, also, subfamilies, pax,
# Nearest to had: has, have, was, were, having, been, reboot, errata,
# Nearest to be: been, refer, have, become, being, continue, is, perform,
# Nearest to such: well, known, these, cursive, opposed, many, grades, kernels,
# Nearest to which: that, this, who, what, there, also, it, usually,
# Average loss at step 52000: 3.452854
# Average loss at step 54000: 3.429644
# Average loss at step 56000: 3.408368
# Average loss at step 58000: 3.283189
# Average loss at step 60000: 3.383013
# Nearest to will: would, can, could, may, should, must, cannot, might,
# Nearest to with: between, clue, lifeboat, vases, while, overarching, through, mjh,
# Nearest to american: italian, british, english, french, veer, african, european, canadian,
# Nearest to most: more, some, many, very, bundesrat, hideo, all, quotients,
# Nearest to six: five, eight, four, seven, nine, three, two, zero,
# Nearest to on: in, upon, avro, through, within, during, under, at,
# Nearest to from: through, into, in, inhabiting, during, across, by, under,
# Nearest to UNK: masts, telegraphs, slabs, athlete, conferred, historian, jean, j,
# Nearest to see: list, gunmen, scanty, nominates, stylized, inexorably, democratization, stoves,
# Nearest to they: we, there, he, you, she, it, these, i,
# Nearest to often: usually, sometimes, generally, commonly, now, frequently, widely, still,
# Nearest to who: which, he, also, she, there, never, they, still,
# Nearest to had: has, have, having, was, were, visas, sevens, marketable,
# Nearest to be: been, become, refer, have, was, is, being, perform,
# Nearest to such: well, these, known, many, other, opposed, heuristic, cursive,
# Nearest to which: that, who, this, what, also, but, it, however,
# Average loss at step 62000: 3.440044
# Average loss at step 64000: 3.359855
# Average loss at step 66000: 3.346818
# Average loss at step 68000: 3.382647
# Average loss at step 70000: 3.371804
# Nearest to will: would, can, could, should, may, must, cannot, might,
# Nearest to with: between, while, by, undertakes, lifeboat, embarking, through, vases,
# Nearest to american: italian, british, french, english, african, veer, australian, german,
# Nearest to most: more, many, some, less, all, bundesrat, versatile, very,
# Nearest to six: seven, eight, nine, five, four, three, two, zero,
# Nearest to on: upon, through, in, avro, towards, fleischer, upcoming, uvs,
# Nearest to from: through, into, during, after, nitrile, across, allegiances, supplanting,
# Nearest to UNK: necessitates, paglia, ahmed, swims, somatic, duron, humanist, fees,
# Nearest to see: but, including, include, boolean, list, and, inexorably, history,
# Nearest to they: we, there, he, you, she, it, i, not,
# Nearest to often: usually, sometimes, generally, commonly, still, now, frequently, traditionally,
# Nearest to who: which, he, she, they, still, never, also, vagus,
# Nearest to had: has, have, was, were, having, visas, since, been,
# Nearest to be: refer, been, have, become, being, was, by, join,
# Nearest to such: well, these, known, many, opposed, heuristic, other, grades,
# Nearest to which: this, that, also, what, still, who, thorough, based,
# Average loss at step 72000: 3.406788
# Average loss at step 74000: 3.384369
# Average loss at step 76000: 3.345459
# Average loss at step 78000: 3.235308
# Average loss at step 80000: 3.368921
# Nearest to will: would, can, could, should, may, must, cannot, might,
# Nearest to with: between, clue, without, while, when, including, using, lagi,
# Nearest to american: british, english, italian, french, european, australian, african, canadian,
# Nearest to most: more, many, some, bundesrat, several, especially, all, less,
# Nearest to six: five, seven, four, eight, nine, zero, three, two,
# Nearest to on: upon, through, in, against, within, avro, enraged, prescribes,
# Nearest to from: into, through, nitrile, using, philibert, across, ther, prescribing,
# Nearest to UNK: chagas, bates, j, website, hittite, nagano, bradley, delusion,
# Nearest to see: list, include, references, external, but, vara, democratization, carnatic,
# Nearest to they: we, you, there, he, it, she, not, these,
# Nearest to often: usually, sometimes, commonly, generally, frequently, now, also, still,
# Nearest to who: he, which, never, she, still, they, vagus, also,
# Nearest to had: has, have, was, having, been, were, ever, visas,
# Nearest to be: become, been, refer, is, being, have, continue, was,
# Nearest to such: well, known, these, opposed, many, kernels, grades, retrieving,
# Nearest to which: this, that, usually, also, who, these, what, but,
# Average loss at step 82000: 3.297251
# Average loss at step 84000: 3.341619
# Average loss at step 86000: 3.343984
# Average loss at step 88000: 3.322631
# Average loss at step 90000: 3.237732
# Nearest to will: would, can, could, should, must, may, cannot, might,
# Nearest to with: between, mjh, metaphase, clue, karaite, within, criminology, lifeboat,
# Nearest to american: british, canadian, english, italian, french, and, german, veer,
# Nearest to most: more, many, some, especially, bundesrat, hideo, all, immersed,
# Nearest to six: eight, four, seven, nine, five, three, zero, two,
# Nearest to on: upon, in, through, at, avro, around, prescribes, about,
# Nearest to from: through, inhabiting, nitrile, in, across, supplanting, into, on,
# Nearest to UNK: jean, claude, poet, composer, physicist, db, author, obstinate,
# Nearest to see: list, include, vara, references, scanty, carnatic, can, stylized,
# Nearest to they: we, he, you, there, she, it, i, these,
# Nearest to often: usually, sometimes, generally, commonly, frequently, still, typically, now,
# Nearest to who: which, he, also, she, still, often, never, vagus,
# Nearest to had: has, have, was, were, having, ak, been, would,
# Nearest to be: become, been, refer, have, were, continue, being, was,
# Nearest to such: well, known, these, opposed, having, served, novgorod, seen,
# Nearest to which: that, this, also, usually, who, what, often, still,
# Average loss at step 92000: 2.737888
# Average loss at step 94000: 3.103411
# Average loss at step 96000: 3.067559
# Average loss at step 98000: 3.220629
# Average loss at step 100000: 3.282898
# Nearest to will: would, can, could, should, must, may, might, cannot,
# Nearest to with: by, between, mjh, clue, despite, including, folder, alerts,
# Nearest to american: british, english, european, canadian, italian, australian, irish, african,
# Nearest to most: more, some, less, many, hideo, quotients, especially, immersed,
# Nearest to six: seven, four, five, eight, nine, three, zero, two,
# Nearest to on: upon, avro, through, in, against, homonyms, havoc, at,
# Nearest to from: through, into, across, upon, yielded, without, nitrile, including,
# Nearest to UNK: lempel, concurred, hagia, meditative, chelmsford, devries, habeas, babur,
# Nearest to see: include, list, references, vara, ambience, boolean, carnatic, agonists,
# Nearest to they: we, he, you, she, there, i, these, it,
# Nearest to often: usually, sometimes, commonly, generally, frequently, also, traditionally, now,
# Nearest to who: which, he, still, also, they, often, subfamilies, vagus,
# Nearest to had: has, have, was, having, never, were, since, recently,
# Nearest to be: become, been, refer, being, have, was, continue, pans,
# Nearest to such: well, known, these, many, opposed, adjusting, having, novgorod,
# Nearest to which: that, this, what, also, who, usually, these, and,
# Average loss at step 102000: 3.286248
# Average loss at step 104000: 3.241848
# Average loss at step 106000: 3.313501
# Average loss at step 108000: 3.363474
# Average loss at step 110000: 3.340607
# Nearest to will: would, could, can, should, must, may, might, cannot,
# Nearest to with: between, using, like, through, lifeboat, criminology, chauffeur, clue,
# Nearest to american: british, australian, english, canadian, italian, german, african, irish,
# Nearest to most: more, some, many, less, especially, past, quotients, among,
# Nearest to six: four, seven, five, eight, three, nine, two, zero,
# Nearest to on: upon, in, through, avro, upcoming, near, beyond, during,
# Nearest to from: through, into, across, nitrile, in, by, during, without,
# Nearest to UNK: le, subfamily, si, tincture, recitation, ethyl, n, cynicism,
# Nearest to see: include, references, list, includes, scanty, carnatic, niccolo, boolean,
# Nearest to they: we, there, he, you, she, these, i, it,
# Nearest to often: usually, sometimes, commonly, frequently, generally, typically, also, still,
# Nearest to who: which, vagus, he, pax, she, they, reawakened, still,
# Nearest to had: have, has, was, having, were, gave, spoke, could,
# Nearest to be: been, become, is, refer, being, was, were, are,
# Nearest to such: well, these, known, many, both, certain, having, several,
# Nearest to which: that, usually, this, who, what, also, however, often,
# Average loss at step 112000: 3.326909
# Average loss at step 114000: 3.225698
# Average loss at step 116000: 3.149932
# Average loss at step 118000: 3.318320
# Average loss at step 120000: 3.296119
# Nearest to will: would, can, could, must, should, might, may, cannot,
# Nearest to with: between, using, clue, criminology, when, lifeboat, by, mik,
# Nearest to american: british, canadian, italian, english, australian, irish, french, african,
# Nearest to most: more, less, many, especially, some, bundesrat, hideo, among,
# Nearest to six: seven, four, eight, five, nine, zero, three, two,
# Nearest to on: upon, in, through, avro, homonyms, within, under, callahan,
# Nearest to from: into, through, lynne, momentous, using, nitrile, across, without,
# Nearest to UNK: reuss, gage, muay, unmixed, gloom, envisaged, freemasons, inferences,
# Nearest to see: include, carnatic, external, references, list, can, cri, boolean,
# Nearest to they: we, there, he, she, you, it, who, these,
# Nearest to often: usually, sometimes, commonly, frequently, generally, typically, now, still,
# Nearest to who: still, he, never, she, they, vagus, generally, already,
# Nearest to had: has, have, having, was, were, took, spoke, proved,
# Nearest to be: been, refer, being, is, become, pans, have, was,
# Nearest to such: well, these, known, having, served, including, many, kernels,
# Nearest to which: that, this, what, usually, these, often, it, but,
# Average loss at step 122000: 3.308369
# Average loss at step 124000: 3.301154
# Average loss at step 126000: 3.341445
# Average loss at step 128000: 3.275697
# Average loss at step 130000: 3.260374
# Nearest to will: would, could, can, must, should, may, might, cannot,
# Nearest to with: between, in, within, and, overarching, vases, under, through,
# Nearest to american: british, english, canadian, italian, australian, african, european, irish,
# Nearest to most: more, especially, many, less, some, bundesrat, among, particularly,
# Nearest to six: seven, eight, four, five, three, nine, zero, two,
# Nearest to on: upon, in, through, within, avro, under, against, during,
# Nearest to from: into, through, across, in, under, balts, supplanting, between,
# Nearest to UNK: movable, lance, arabic, blum, swerve, zx, astonishing, nacional,
# Nearest to see: include, list, external, includes, unexplored, references, carnatic, axumite,
# Nearest to they: we, there, he, she, you, it, these, lala,
# Nearest to often: sometimes, usually, commonly, frequently, generally, typically, still, now,
# Nearest to who: he, she, which, never, still, already, they, generally,
# Nearest to had: has, have, having, was, were, marketable, proved, took,
# Nearest to be: been, refer, become, pans, was, join, produce, resemble,
# Nearest to such: well, these, known, having, including, many, served, gorgeous,
# Nearest to which: that, this, also, often, but, usually, what, who,
# Average loss at step 132000: 2.997950
# Average loss at step 134000: 3.154200
# Average loss at step 136000: 3.258446
# Average loss at step 138000: 3.118782
# Average loss at step 140000: 3.242314
# Nearest to will: would, could, can, must, should, might, cannot, may,
# Nearest to with: between, by, mjh, criminology, overarching, when, alerts, vases,
# Nearest to american: canadian, english, british, australian, italian, german, french, dutch,
# Nearest to most: more, many, less, some, especially, among, particularly, hideo,
# Nearest to six: seven, eight, five, four, nine, three, two, zero,
# Nearest to on: upon, in, avro, through, within, around, near, melvyn,
# Nearest to from: through, across, inhabiting, into, via, lynne, in, before,
# Nearest to UNK: plagiarized, elder, brutality, tumours, legalised, adams, bunk, friend,
# Nearest to see: include, references, external, coordinates, carnatic, list, includes, scanty,
# Nearest to they: we, he, there, she, you, it, these, eventually,
# Nearest to often: sometimes, usually, commonly, generally, frequently, typically, still, now,
# Nearest to who: which, never, he, also, she, already, still, vagus,
# Nearest to had: has, have, were, having, was, since, recently, proved,
# Nearest to be: been, have, become, refer, were, is, are, being,
# Nearest to such: well, having, known, including, these, exist, dtmf, ayla,
# Nearest to which: that, this, who, what, also, but, usually, accordingly,
# Average loss at step 142000: 3.340608
# Average loss at step 144000: 3.288907
# Average loss at step 146000: 3.204906
# Average loss at step 148000: 3.178343
# Average loss at step 150000: 3.291061
# Nearest to will: would, could, can, must, should, might, may, cannot,
# Nearest to with: between, without, when, by, through, mjh, within, soaemias,
# Nearest to american: british, english, canadian, australian, italian, german, french, dutch,
# Nearest to most: more, many, less, some, especially, hideo, versatile, particularly,
# Nearest to six: seven, four, eight, five, nine, three, zero, two,
# Nearest to on: upon, avro, against, within, through, in, upcoming, uncompressed,
# Nearest to from: into, through, across, balts, via, distributist, inhabiting, oft,
# Nearest to UNK: investigators, attila, seduction, espousing, smoothly, hinterland, decrement, whispering,
# Nearest to see: include, references, carnatic, external, list, can, includes, unexplored,
# Nearest to they: we, there, he, she, you, these, it, eventually,
# Nearest to often: sometimes, usually, generally, commonly, typically, frequently, now, still,
# Nearest to who: she, he, never, which, they, already, vagus, generally,
# Nearest to had: has, have, was, having, were, never, since, proved,
# Nearest to be: been, become, refer, was, have, is, pans, continue,
# Nearest to such: well, these, known, including, having, additional, dtmf, opposed,
# Nearest to which: that, this, usually, what, also, who, typically, these,
# Average loss at step 152000: 3.322242
# Average loss at step 154000: 3.334999
# Average loss at step 156000: 3.269415
# Average loss at step 158000: 3.231287
# Average loss at step 160000: 3.286744
# Nearest to will: would, could, should, must, can, might, cannot, may,
# Nearest to with: between, by, using, in, through, without, prefrontal, including,
# Nearest to american: canadian, british, english, australian, italian, african, russian, indian,
# Nearest to most: many, more, less, some, especially, all, hideo, versatile,
# Nearest to six: seven, five, nine, eight, four, three, zero, two,
# Nearest to on: upon, within, avro, through, against, in, towards, during,
# Nearest to from: through, into, across, inhabiting, balts, oft, in, via,
# Nearest to UNK: kashubian, aelia, ahmed, fran, kasner, disobeyed, die, duron,
# Nearest to see: include, references, carnatic, list, vara, stylized, refer, external,
# Nearest to they: we, he, there, she, you, it, these, never,
# Nearest to often: sometimes, usually, frequently, commonly, generally, typically, traditionally, still,
# Nearest to who: which, she, never, he, often, still, that, generally,
# Nearest to had: has, have, having, were, was, since, never, gave,
# Nearest to be: become, been, have, refer, is, was, being, continue,
# Nearest to such: well, these, having, known, including, additional, multiple, notable,
# Nearest to which: that, who, this, usually, also, typically, but, still,
# Average loss at step 162000: 3.219158
# Average loss at step 164000: 3.244619
# Average loss at step 166000: 3.232507
# Average loss at step 168000: 3.198234
# Average loss at step 170000: 3.164419
# Nearest to will: would, could, should, can, must, might, cannot, may,
# Nearest to with: between, in, pinpoint, criminology, bamako, within, pandemic, consecrations,
# Nearest to american: english, canadian, australian, british, italian, dutch, french, german,
# Nearest to most: more, less, many, especially, versatile, some, cause, quotients,
# Nearest to six: five, four, seven, eight, three, nine, zero, two,
# Nearest to on: upon, within, in, avro, through, near, alfredo, during,
# Nearest to from: through, into, across, by, via, between, during, before,
# Nearest to UNK: tincture, hippies, sternberg, tertullian, antidisestablishmentarianism, gaulle, mitigating, obnoxious,
# Nearest to see: references, include, list, consider, includes, vara, external, carnatic,
# Nearest to they: we, he, there, she, you, it, these, eventually,
# Nearest to often: sometimes, usually, frequently, commonly, typically, generally, traditionally, still,
# Nearest to who: often, which, she, never, he, they, still, vagus,
# Nearest to had: has, have, having, were, was, never, eventually, fled,
# Nearest to be: become, been, is, was, refer, have, continue, were,
# Nearest to such: well, having, these, known, including, certain, additional, defined,
# Nearest to which: that, this, who, these, but, usually, what, also,
# Average loss at step 172000: 3.183714
# Average loss at step 174000: 3.254997
# Average loss at step 176000: 3.247035
# Average loss at step 178000: 3.228060
# Average loss at step 180000: 3.247036
# Nearest to will: would, could, can, should, must, cannot, may, might,
# Nearest to with: between, including, using, publishes, prefrontal, nutritional, forming, by,
# Nearest to american: canadian, english, british, italian, scottish, australian, french, dutch,
# Nearest to most: more, less, especially, many, versatile, particularly, foregoing, some,
# Nearest to six: four, eight, five, seven, nine, three, zero, two,
# Nearest to on: upon, avro, through, near, melvyn, within, against, regarding,
# Nearest to from: through, into, across, via, lynne, before, dekalb, without,
# Nearest to UNK: rio, el, antigonus, claude, gallagher, covalently, masts, et,
# Nearest to see: include, references, list, includes, external, consider, vara, stylized,
# Nearest to they: we, there, he, you, she, these, it, namespaces,
# Nearest to often: sometimes, usually, frequently, commonly, typically, generally, traditionally, still,
# Nearest to who: she, which, never, already, he, often, actually, vagus,
# Nearest to had: has, have, having, was, were, suffered, never, attempted,
# Nearest to be: been, become, is, was, refer, are, have, perform,
# Nearest to such: well, including, these, known, having, regarded, opposed, viewed,
# Nearest to which: that, this, these, who, typically, also, usually, midwifery,
# Average loss at step 182000: 3.253891
# Average loss at step 184000: 3.289540
# Average loss at step 186000: 3.271947
# Average loss at step 188000: 3.268391
# Average loss at step 190000: 3.225172
# Nearest to will: would, can, could, must, should, may, might, cannot,
# Nearest to with: between, overarching, in, by, and, nutritional, of, migraine,
# Nearest to american: australian, canadian, british, italian, african, english, irish, other,
# Nearest to most: more, many, less, especially, particularly, some, foregoing, versatile,
# Nearest to six: seven, four, eight, five, nine, three, zero, two,
# Nearest to on: upon, in, within, during, near, upcoming, at, avro,
# Nearest to from: across, through, via, into, in, of, during, mclachlan,
# Nearest to UNK: rio, topsy, meditator, brecht, hump, prado, joys, hochschule,
# Nearest to see: include, list, includes, references, external, bixby, carnatic, refer,
# Nearest to they: we, there, he, you, she, these, i, it,
# Nearest to often: sometimes, usually, frequently, commonly, typically, generally, traditionally, normally,
# Nearest to who: which, often, generally, already, never, she, actually, still,
# Nearest to had: have, has, was, never, having, were, suffered, attempted,
# Nearest to be: been, become, refer, have, easily, appoint, form, pans,
# Nearest to such: well, including, these, known, having, certain, regarded, vacuole,
# Nearest to which: that, this, but, also, who, usually, pyrotechnics, these,
# Average loss at step 192000: 3.097194
# Average loss at step 194000: 3.250636
# Average loss at step 196000: 3.265168
# Average loss at step 198000: 3.276871
# Average loss at step 200000: 3.275473
# Nearest to will: would, must, could, can, should, might, may, cannot,
# Nearest to with: between, when, lessing, mjh, draws, by, including, in,
# Nearest to american: canadian, australian, italian, english, irish, british, european, african,
# Nearest to most: more, less, especially, many, particularly, libertarianism, among, some,
# Nearest to six: four, eight, five, nine, seven, three, two, zero,
# Nearest to on: upon, in, near, avro, through, at, within, homonyms,
# Nearest to from: through, via, into, across, including, by, in, nitrile,
# Nearest to UNK: joyce, disobeyed, reckoning, db, murakami, referenda, cadiz, edelman,
# Nearest to see: include, list, references, refer, seem, cossiga, includes, external,
# Nearest to they: we, you, he, there, she, it, i, these,
# Nearest to often: sometimes, usually, frequently, commonly, typically, generally, traditionally, still,
# Nearest to who: which, generally, already, richie, actually, usually, often, never,
# Nearest to had: has, have, was, having, were, never, suffered, gave,
# Nearest to be: been, become, refer, have, being, form, remain, get,
# Nearest to such: these, well, having, known, including, certain, serve, regarded,
# Nearest to which: this, that, also, who, usually, typically, actually, what,
# Average loss at step 202000: 3.202743
# Average loss at step 204000: 3.239023
# Average loss at step 206000: 3.283364
# Average loss at step 208000: 3.261687
# Average loss at step 210000: 3.278703
# Nearest to will: would, could, must, can, should, cannot, might, may,
# Nearest to with: between, including, in, via, overarching, when, lessing, recompense,
# Nearest to american: canadian, australian, italian, british, idiot, international, english, indian,
# Nearest to most: more, less, some, many, foregoing, particularly, especially, all,
# Nearest to six: four, eight, five, seven, nine, three, zero, two,
# Nearest to on: upon, in, avro, through, near, at, upcoming, fleischer,
# Nearest to from: via, through, across, in, by, under, into, after,
# Nearest to UNK: ne, svg, tincture, praia, gilchrist, kasner, ahmed, ludwig,
# Nearest to see: include, list, references, external, includes, refer, niccolo, bixby,
# Nearest to they: we, he, there, you, she, it, these, soon,
# Nearest to often: usually, sometimes, frequently, typically, commonly, generally, traditionally, rarely,
# Nearest to who: which, generally, already, he, usually, actually, vagus, still,
# Nearest to had: has, have, having, was, gave, attempted, were, suffered,
# Nearest to be: been, was, become, refer, get, have, being, form,
# Nearest to such: well, having, these, known, certain, including, defined, described,
# Nearest to which: that, this, who, usually, typically, actually, also, what,
# Average loss at step 212000: 3.233896
# Average loss at step 214000: 3.231798
# Average loss at step 216000: 3.040682
# Average loss at step 218000: 3.134332
# Average loss at step 220000: 3.262731
# Nearest to will: would, could, must, should, can, may, might, cannot,
# Nearest to with: between, criminology, when, including, karaite, clue, using, lifeboat,
# Nearest to american: australian, canadian, italian, english, british, indian, european, african,
# Nearest to most: less, more, many, particularly, some, especially, foregoing, bundesrat,
# Nearest to six: eight, seven, five, four, three, nine, two, zero,
# Nearest to on: upon, avro, through, regarding, uvs, within, melvyn, in,
# Nearest to from: across, via, through, into, unavailable, lynne, distributist, oft,
# Nearest to UNK: augustin, necessitates, praia, valle, masts, aise, chez, storey,
# Nearest to see: include, list, references, external, stylized, bixby, includes, cossiga,
# Nearest to they: we, there, you, he, she, it, these, not,
# Nearest to often: sometimes, usually, frequently, commonly, generally, typically, traditionally, also,
# Nearest to who: which, he, actually, normally, often, she, generally, vagus,
# Nearest to had: has, have, having, was, tries, gave, suffered, never,
# Nearest to be: been, become, refer, get, remain, instruct, have, easily,
# Nearest to such: well, these, known, having, including, opposed, being, chymotrypsin,
# Nearest to which: that, this, usually, typically, who, what, but, these,
# Average loss at step 222000: 3.243812
# Average loss at step 224000: 3.203239
# Average loss at step 226000: 3.241284
# Average loss at step 228000: 3.228205
# Average loss at step 230000: 3.187304
# Nearest to will: would, must, could, should, can, cannot, may, might,
# Nearest to with: between, taif, and, overarching, when, pinpoint, lifeboat, soaemias,
# Nearest to american: australian, canadian, british, italian, irish, english, scottish, dutch,
# Nearest to most: less, more, many, some, particularly, especially, foregoing, versatile,
# Nearest to six: four, eight, five, seven, nine, three, two, zero,
# Nearest to on: upon, avro, in, uncompressed, melvyn, through, uvs, adriatic,
# Nearest to from: through, via, into, across, between, lynne, oft, inhabiting,
# Nearest to UNK: rio, gen, merseburg, freshness, loader, scaly, blum, ja,
# Nearest to see: list, references, include, external, includes, inexorably, falco, carnatic,
# Nearest to they: we, he, there, she, you, it, these, amalric,
# Nearest to often: sometimes, usually, commonly, frequently, generally, typically, traditionally, actually,
# Nearest to who: he, which, already, actually, still, never, vagus, she,
# Nearest to had: has, have, having, was, were, gave, tried, tries,
# Nearest to be: been, become, refer, have, pans, remain, easily, being,
# Nearest to such: well, these, having, known, regarded, certain, follows, classified,
# Nearest to which: usually, this, that, typically, actually, these, who, also,
# Average loss at step 232000: 3.243766
# Average loss at step 234000: 3.253403
# Average loss at step 236000: 3.291626
# Average loss at step 238000: 3.289960
# Average loss at step 240000: 3.264583
# Nearest to will: would, must, could, can, should, might, cannot, may,
# Nearest to with: between, taif, coq, in, soaemias, mik, fortran, via,
# Nearest to american: australian, italian, canadian, british, dutch, french, german, irish,
# Nearest to most: more, less, particularly, especially, many, some, foregoing, several,
# Nearest to six: eight, seven, five, nine, four, three, zero, two,
# Nearest to on: upon, in, avro, through, regarding, melvyn, upcoming, uncompressed,
# Nearest to from: via, through, across, beneath, into, lynne, between, nitrile,
# Nearest to UNK: christophe, recherche, seduction, ra, valle, brow, gen, merseburg,
# Nearest to see: references, includes, include, external, refer, list, stylized, carnatic,
# Nearest to they: we, he, there, she, you, it, these, i,
# Nearest to often: sometimes, commonly, frequently, usually, generally, typically, traditionally, actually,
# Nearest to who: which, actually, often, already, he, still, she, typically,
# Nearest to had: has, have, having, were, was, tries, since, never,
# Nearest to be: been, become, refer, is, have, get, being, remain,
# Nearest to such: well, these, certain, known, dtmf, viewed, exist, regarded,
# Nearest to which: that, this, who, what, actually, usually, typically, but,
# Average loss at step 242000: 3.242226
# Average loss at step 244000: 3.267549
# Average loss at step 246000: 3.274560
# Average loss at step 248000: 3.151467
# Average loss at step 250000: 3.232881
# Nearest to will: would, must, can, should, could, cannot, might, may,
# Nearest to with: using, containing, for, in, between, when, clue, overarching,
# Nearest to american: canadian, british, australian, italian, english, french, irish, scottish,
# Nearest to most: more, less, many, especially, particularly, some, several, foregoing,
# Nearest to six: seven, eight, nine, five, four, three, zero, two,
# Nearest to on: upon, avro, in, melvyn, through, spliced, near, upcoming,
# Nearest to from: via, through, across, nitrile, into, lynne, in, beneath,
# Nearest to UNK: seduction, cur, bouncing, recursive, simply, chagas, silent, underwear,
# Nearest to see: references, list, include, external, refer, includes, carnatic, according,
# Nearest to they: we, there, he, you, she, these, it, etc,
# Nearest to often: sometimes, usually, commonly, generally, frequently, typically, normally, now,
# Nearest to who: actually, he, still, typically, which, already, never, generally,
# Nearest to had: has, have, having, was, were, tries, since, wanted,
# Nearest to be: been, become, refer, is, pans, are, easily, being,
# Nearest to such: well, known, follows, certain, dtmf, these, adjusting, kernels,
# Nearest to which: that, this, actually, typically, usually, what, also, but,
# Average loss at step 252000: 3.133115
# Average loss at step 254000: 3.267946
# Average loss at step 256000: 3.175563
# Average loss at step 258000: 3.160647
# Average loss at step 260000: 3.239097
# Nearest to will: would, can, should, could, might, cannot, must, may,
# Nearest to with: between, in, soaemias, mjh, by, karo, phimosis, draws,
# Nearest to american: canadian, australian, italian, british, english, irish, scottish, indian,
# Nearest to most: more, particularly, less, many, especially, some, several, immersed,
# Nearest to six: seven, four, five, eight, nine, three, zero, two,
# Nearest to on: upon, in, avro, melvyn, regarding, at, near, against,
# Nearest to from: via, through, across, in, nitrile, oft, into, unavailable,
# Nearest to UNK: ablaze, eon, ethyl, durand, paisley, rajonas, dar, habits,
# Nearest to see: refer, references, include, list, includes, consider, tend, meet,
# Nearest to they: we, he, you, there, she, these, it, i,
# Nearest to often: sometimes, usually, generally, frequently, commonly, typically, actually, traditionally,
# Nearest to who: which, already, often, still, actually, never, also, typically,
# Nearest to had: has, have, was, were, wanted, since, having, attempted,
# Nearest to be: been, become, easily, refer, being, pans, get, is,
# Nearest to such: well, certain, known, these, including, having, dtmf, those,
# Nearest to which: that, this, who, also, actually, typically, what, but,
# Average loss at step 262000: 3.201833
# Average loss at step 264000: 3.042206
# Average loss at step 266000: 3.164077
# Average loss at step 268000: 3.166992
# Average loss at step 270000: 3.172473
# Nearest to will: would, should, can, could, must, might, cannot, may,
# Nearest to with: between, involving, in, via, requires, reprogramming, by, mjh,
# Nearest to american: canadian, australian, british, english, italian, indian, irish, african,
# Nearest to most: more, particularly, especially, less, many, hideo, libertarianism, some,
# Nearest to six: five, seven, four, eight, nine, three, two, zero,
# Nearest to on: upon, avro, concerning, in, near, at, through, regarding,
# Nearest to from: via, inhabiting, through, into, across, mclachlan, by, luanda,
# Nearest to UNK: tincture, sternberg, kobayashi, theodora, recherche, fft, disobeyed, meister,
# Nearest to see: list, references, refer, include, includes, according, violate, tend,
# Nearest to they: we, he, you, there, she, it, these, soon,
# Nearest to often: sometimes, usually, typically, generally, frequently, commonly, actually, normally,
# Nearest to who: still, already, actually, typically, often, she, never, which,
# Nearest to had: has, have, was, were, never, gave, wanted, having,
# Nearest to be: been, become, have, refer, easily, get, is, remain,
# Nearest to such: certain, well, known, these, having, possessing, follows, acting,
# Nearest to which: that, this, what, actually, accordingly, typically, also, fluctuations,
# Average loss at step 272000: 3.202465
# Average loss at step 274000: 3.175083
# Average loss at step 276000: 3.185276
# Average loss at step 278000: 3.114906
# Average loss at step 280000: 3.051384
# Nearest to will: would, should, could, must, may, can, might, cannot,
# Nearest to with: between, including, overarching, by, mjh, lifeboat, involving, in,
# Nearest to american: canadian, italian, british, australian, african, french, german, european,
# Nearest to most: more, less, especially, particularly, bundesrat, some, hideo, foregoing,
# Nearest to six: five, four, seven, eight, three, nine, zero, two,
# Nearest to on: upon, avro, in, upcoming, uvs, boudinot, melvyn, fleischer,
# Nearest to from: through, via, across, in, between, inhabiting, into, including,
# Nearest to UNK: educator, eoin, cain, grandstand, fv, augustin, ferrell, anderson,
# Nearest to see: references, list, refer, includes, include, external, vara, tend,
# Nearest to they: we, he, she, there, you, it, these, soon,
# Nearest to often: sometimes, frequently, usually, typically, generally, commonly, traditionally, normally,
# Nearest to who: which, actually, still, he, already, she, also, never,
# Nearest to had: has, have, having, was, were, never, suffered, wanted,
# Nearest to be: been, become, refer, get, pans, remain, have, easily,
# Nearest to such: well, these, follows, known, possessing, having, certain, acting,
# Nearest to which: that, also, this, who, actually, typically, accordingly, initially,
# Average loss at step 282000: 3.179952
# Average loss at step 284000: 3.056604
# Average loss at step 286000: 3.104367
# Average loss at step 288000: 3.162027
# Average loss at step 290000: 3.033228
# Nearest to will: would, must, should, could, can, might, cannot, may,
# Nearest to with: between, mik, mjh, makes, bamako, draws, alerts, involving,
# Nearest to american: canadian, australian, british, italian, english, russian, dutch, irish,
# Nearest to most: more, less, particularly, hideo, especially, foregoing, many, some,
# Nearest to six: seven, five, eight, four, nine, three, two, zero,
# Nearest to on: upon, near, in, avro, within, under, through, around,
# Nearest to from: via, through, across, beneath, preprocessor, mclachlan, dekalb, inhabiting,
# Nearest to UNK: seduction, praia, hernandez, chez, philipp, alexandre, graf, kaj,
# Nearest to see: includes, references, external, refer, list, cossiga, vara, bpm,
# Nearest to they: we, he, you, she, there, these, it, soon,
# Nearest to often: sometimes, frequently, commonly, typically, usually, generally, traditionally, normally,
# Nearest to who: which, he, she, actually, still, adys, already, pax,
# Nearest to had: has, have, having, never, was, tries, attempted, tried,
# Nearest to be: been, become, easily, have, refer, pans, was, contain,
# Nearest to such: well, known, follows, these, opposed, certain, regarded, possessing,
# Nearest to which: that, actually, this, who, typically, also, usually, instead,
# Average loss at step 292000: 3.220270
# Average loss at step 294000: 3.166141
# Average loss at step 296000: 3.152110
# Average loss at step 298000: 2.916269
# Average loss at step 300000: 3.208431
# Nearest to will: would, can, must, could, might, should, cannot, may,
# Nearest to with: between, when, overarching, reprogramming, using, in, recompense, vases,
# Nearest to american: australian, canadian, italian, british, african, irish, european, amateur,
# Nearest to most: less, more, many, particularly, some, especially, hideo, bundesrat,
# Nearest to six: seven, five, eight, four, nine, three, two, zero,
# Nearest to on: upon, near, in, at, regarding, avro, through, dato,
# Nearest to from: via, through, across, into, inhabiting, lynne, mclachlan, yielded,
# Nearest to UNK: storey, una, shepard, sacra, ethyl, covalently, scaly, ctus,
# Nearest to see: includes, list, references, refer, include, external, vara, lists,
# Nearest to they: we, he, you, there, she, it, i, these,
# Nearest to often: sometimes, frequently, usually, commonly, typically, generally, normally, traditionally,
# Nearest to who: he, actually, already, she, which, still, jubal, gunther,
# Nearest to had: has, have, having, was, never, tries, were, gave,
# Nearest to be: been, become, was, refer, easily, get, pans, being,
# Nearest to such: well, these, certain, known, few, follows, opposed, possessing,
# Nearest to which: that, this, also, actually, typically, what, accordingly, usually,

# %%
num_points = 100

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
